# %% [markdown]
# # Registry Demo

# %% [markdown]
# ## Setup

# %%
import registry
import cdflibS3 as cdflib
import matplotlib.pyplot as plt
from pprint import pprint

# %%
#import logging
#logging.getLogger().setLevel(logging.DEBUG)

# %% [markdown]
# ## Params

# %% [markdown]
# ## Searching for data with EntireCatalogSearch

# %%
search = registry.EntireCatalogSearch()
# Out:
# WARNING:root:Failed Local Catalog Fetches (1/2):
# [
#     GSFC HelioCloud Set 1 (us-east-1)
# ]

# %%
search.search_by_id('mms1_feeps')
# Out:
# [{'id': 'mms1_feeps_brst_electron',
#   'loc': 's3://helio-public/MMS/mms1/feeps/brst/l2/electron/',
#   'title': 'mms1/feeps/brst/l2/electron/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf',
#   'description': 'Optional description for dataset',
#   'resourceURL': 'optional identifier e.g. SPASE ID',
#   'creationDate': '2023-04-05T00:00:00Z',
#   'citation': 'optional how to cite this dataset, DOI or similar',
#   'contact': 'optional contact info, SPASE ID, email, or ORCID',
#   'aboutURL': 'optional website URL for info, team, etc'},
#  {'id': 'mms1_feeps_brst_ion',
#   'loc': 's3://helio-public/MMS/mms1/feeps/brst/l2/ion/',
#   'title': 'mms1/feeps/brst/l2/ion/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf'},
#  {'id': 'mms1_feeps_srvy_electron',
#   'loc': 's3://helio-public/MMS/mms1/feeps/srvy/l2/electron/',
#   'title': 'mms1/feeps/srvy/l2/electron/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf'},
#  {'id': 'mms1_feeps_srvy_ion',
#   'loc': 's3://helio-public/MMS/mms1/feeps/srvy/l2/ion/',
#   'title': 'mms1/feeps/srvy/l2/ion/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf'}]

# %%
search.search_by_id('srvy_ion')
# Out:
# [{'id': 'mms1_feeps_srvy_ion',
#   'loc': 's3://helio-public/MMS/mms1/feeps/srvy/l2/ion/',
#   'title': 'mms1/feeps/srvy/l2/ion/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf'},
#  {'id': 'mms2_feeps_srvy_ion',
#   'loc': 's3://helio-public/MMS/mms2/feeps/srvy/l2/ion/',
#   'title': 'mms2/feeps/srvy/l2/ion/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf'},
#  {'id': 'mms3_feeps_srvy_ion',
#   'loc': 's3://helio-public/MMS/mms3/feeps/srvy/l2/ion/',
#   'title': 'mms3/feeps/srvy/l2/ion/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf'},
#  {'id': 'mms4_feeps_srvy_ion',
#   'loc': 's3://helio-public/MMS/mms4/feeps/srvy/l2/ion/',
#   'title': 'mms4/feeps/srvy/l2/ion/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf'}]

# %%
search.search_by_title('mms1/fpi/b')
# Out:
# [{'id': 'mms1_fpi_brst_des-dist',
#   'loc': 's3://helio-public/MMS/mms1/fpi/brst/l2/des-dist/',
#   'title': 'mms1/fpi/brst/l2/des-dist/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf'},
#  {'id': 'mms1_fpi_brst_des-moms',
#   'loc': 's3://helio-public/MMS/mms1/fpi/brst/l2/des-moms/',
#   'title': 'mms1/fpi/brst/l2/des-moms/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf'},
#  {'id': 'mms1_fpi_brst_dis-dist',
#   'loc': 's3://helio-public/MMS/mms1/fpi/brst/l2/dis-dist/',
#   'title': 'mms1/fpi/brst/l2/dis-dist/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf'},
#  {'id': 'mms1_fpi_brst_dis-moms',
#   'loc': 's3://helio-public/MMS/mms1/fpi/brst/l2/dis-moms/',
#   'title': 'mms1/fpi/brst/l2/dis-moms/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf'}]

# %%
search.search_by_title('des-dist')[:2]
# Out:
# [{'id': 'mms1_fpi_brst_des-dist',
#   'loc': 's3://helio-public/MMS/mms1/fpi/brst/l2/des-dist/',
#   'title': 'mms1/fpi/brst/l2/des-dist/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf'},
#  {'id': 'mms1_fpi_fast_des-dist',
#   'loc': 's3://helio-public/MMS/mms1/fpi/fast/l2/des-dist/',
#   'title': 'mms1/fpi/fast/l2/des-dist/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf'}]

# %%
search.search_by_keywords(['mms2', 'brst', 'apples'])[:3]
# Out:
# [{'id': 'mms2_feeps_brst_electron',
#   'loc': 's3://helio-public/MMS/mms2/feeps/brst/l2/electron/',
#   'title': 'mms2/feeps/brst/l2/electron/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf'},
#  {'id': 'mms2_feeps_brst_ion',
#   'loc': 's3://helio-public/MMS/mms2/feeps/brst/l2/ion/',
#   'title': 'mms2/feeps/brst/l2/ion/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf'},
#  {'id': 'mms2_fgm_brst',
#   'loc': 's3://helio-public/MMS/mms2/fgm/brst/l2/',
#   'title': 'mms2/fgm/brst/l2/',
#   'startDate': '2015-06-01T00:00:00Z',
#   'stopDate': '2021-12-31T23:59:00Z',
#   'modificationDate': '2023-03-08T00:00:00Z',
#   'indexformat': 'csv',
#   'fileformat': 'cdf'}]

# %% [markdown]
# ## Working with the global catalog (..the name)

# %%
cr = registry.CatalogRegistry()

# %%
cr.get_catalog()
# Out:
# {'CloudMe': '0.1',
#  'modificationDate': '2022-01-01T00:00Z',
#  'registry': [{'endpoint': 's3://helio-public/',
#    'name': 'GSFC HelioCloud Public Temp',
#    'region': 'us-east-1'},
#   {'endpoint': 's3://gov-nasa-hdrl-data1/',
#    'name': 'GSFC HelioCloud Set 1',
#    'region': 'us-east-1'}]}

# %%
cr.get_registry()
# Out:
# [{'endpoint': 's3://helio-public/',
#   'name': 'GSFC HelioCloud Public Temp',
#   'region': 'us-east-1'},
#  {'endpoint': 's3://gov-nasa-hdrl-data1/',
#   'name': 'GSFC HelioCloud Set 1',
#   'region': 'us-east-1'}]

# %%
cr.get_entries()
# Out:
# [('GSFC HelioCloud Public Temp', 'us-east-1'),
#  ('GSFC HelioCloud Set 1', 'us-east-1')]

# %%
endpoint = cr.get_endpoint('GSFC HelioCloud Public Temp')
endpoint
# Out:
# 's3://helio-public/'

# %%
cr.catalog
# Out:
# {'CloudMe': '0.1',
#  'modificationDate': '2022-01-01T00:00Z',
#  'registry': [{'endpoint': 's3://helio-public/',
#    'name': 'GSFC HelioCloud Public Temp',
#    'region': 'us-east-1'},
#   {'endpoint': 's3://gov-nasa-hdrl-data1/',
#    'name': 'GSFC HelioCloud Set 1',
#    'region': 'us-east-1'}]}

# %% [markdown]
# ## Working with a local catalog

# %%
fr = registry.FileRegistry(endpoint, cache=True)

# %%
fr.get_catalog()
# Out:
# {'Cloudy': '0.2',
#  'endpoint': 's3://helio-public/',
#  'name': 'GSFC HelioCloud',
#  'contact': 'Dr. Contact, dr_contact@example.com',
#  'description': 'Optional description of this collection',
#  'citation': 'Optional how to cite, preferably a DOI for the server',
#  'catalog': [{'id': 'mms1_feeps_brst_electron',
#    'loc': 's3://helio-public/MMS/mms1/feeps/brst/l2/electron/',
#    'title': 'mms1/feeps/brst/l2/electron/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf',
#    'description': 'Optional description for dataset',
#    'resourceURL': 'optional identifier e.g. SPASE ID',
#    'creationDate': '2023-04-05T00:00:00Z',
#    'citation': 'optional how to cite this dataset, DOI or similar',
#    'contact': 'optional contact info, SPASE ID, email, or ORCID',
#    'aboutURL': 'optional website URL for info, team, etc'},
#   {'id': 'mms1_feeps_brst_ion',
#    'loc': 's3://helio-public/MMS/mms1/feeps/brst/l2/ion/',
#    'title': 'mms1/feeps/brst/l2/ion/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms1_feeps_srvy_electron',
#    'loc': 's3://helio-public/MMS/mms1/feeps/srvy/l2/electron/',
#    'title': 'mms1/feeps/srvy/l2/electron/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms1_feeps_srvy_ion',
#    'loc': 's3://helio-public/MMS/mms1/feeps/srvy/l2/ion/',
#    'title': 'mms1/feeps/srvy/l2/ion/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms1_fgm_brst',
#    'loc': 's3://helio-public/MMS/mms1/fgm/brst/l2/',
#    'title': 'mms1/fgm/brst/l2/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms1_fgm_srvy',
#    'loc': 's3://helio-public/MMS/mms1/fgm/srvy/l2/',
#    'title': 'mms1/fgm/srvy/l2/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms1_fpi_brst_des-dist',
#    'loc': 's3://helio-public/MMS/mms1/fpi/brst/l2/des-dist/',
#    'title': 'mms1/fpi/brst/l2/des-dist/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms1_fpi_brst_des-moms',
#    'loc': 's3://helio-public/MMS/mms1/fpi/brst/l2/des-moms/',
#    'title': 'mms1/fpi/brst/l2/des-moms/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms1_fpi_brst_dis-dist',
#    'loc': 's3://helio-public/MMS/mms1/fpi/brst/l2/dis-dist/',
#    'title': 'mms1/fpi/brst/l2/dis-dist/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms1_fpi_brst_dis-moms',
#    'loc': 's3://helio-public/MMS/mms1/fpi/brst/l2/dis-moms/',
#    'title': 'mms1/fpi/brst/l2/dis-moms/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms1_fpi_fast_des-dist',
#    'loc': 's3://helio-public/MMS/mms1/fpi/fast/l2/des-dist/',
#    'title': 'mms1/fpi/fast/l2/des-dist/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms1_fpi_fast_des-moms',
#    'loc': 's3://helio-public/MMS/mms1/fpi/fast/l2/des-moms/',
#    'title': 'mms1/fpi/fast/l2/des-moms/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms1_fpi_fast_dis-dist',
#    'loc': 's3://helio-public/MMS/mms1/fpi/fast/l2/dis-dist/',
#    'title': 'mms1/fpi/fast/l2/dis-dist/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms1_fpi_fast_dis-moms',
#    'loc': 's3://helio-public/MMS/mms1/fpi/fast/l2/dis-moms/',
#    'title': 'mms1/fpi/fast/l2/dis-moms/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms1_mec_brst_epht89d',
#    'loc': 's3://helio-public/MMS/mms1/mec/brst/l2/epht89d/',
#    'title': 'mms1/mec/brst/l2/epht89d/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms1_mec_srvy_epht89d',
#    'loc': 's3://helio-public/MMS/mms1/mec/srvy/l2/epht89d/',
#    'title': 'mms1/mec/srvy/l2/epht89d/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms2_feeps_brst_electron',
#    'loc': 's3://helio-public/MMS/mms2/feeps/brst/l2/electron/',
#    'title': 'mms2/feeps/brst/l2/electron/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms2_feeps_brst_ion',
#    'loc': 's3://helio-public/MMS/mms2/feeps/brst/l2/ion/',
#    'title': 'mms2/feeps/brst/l2/ion/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms2_feeps_srvy_electron',
#    'loc': 's3://helio-public/MMS/mms2/feeps/srvy/l2/electron/',
#    'title': 'mms2/feeps/srvy/l2/electron/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms2_feeps_srvy_ion',
#    'loc': 's3://helio-public/MMS/mms2/feeps/srvy/l2/ion/',
#    'title': 'mms2/feeps/srvy/l2/ion/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms2_fgm_brst',
#    'loc': 's3://helio-public/MMS/mms2/fgm/brst/l2/',
#    'title': 'mms2/fgm/brst/l2/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms2_fgm_srvy',
#    'loc': 's3://helio-public/MMS/mms2/fgm/srvy/l2/',
#    'title': 'mms2/fgm/srvy/l2/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms2_fpi_brst_des-dist',
#    'loc': 's3://helio-public/MMS/mms2/fpi/brst/l2/des-dist/',
#    'title': 'mms2/fpi/brst/l2/des-dist/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms2_fpi_brst_des-moms',
#    'loc': 's3://helio-public/MMS/mms2/fpi/brst/l2/des-moms/',
#    'title': 'mms2/fpi/brst/l2/des-moms/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms2_fpi_brst_dis-dist',
#    'loc': 's3://helio-public/MMS/mms2/fpi/brst/l2/dis-dist/',
#    'title': 'mms2/fpi/brst/l2/dis-dist/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms2_fpi_brst_dis-moms',
#    'loc': 's3://helio-public/MMS/mms2/fpi/brst/l2/dis-moms/',
#    'title': 'mms2/fpi/brst/l2/dis-moms/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms2_fpi_fast_des-dist',
#    'loc': 's3://helio-public/MMS/mms2/fpi/fast/l2/des-dist/',
#    'title': 'mms2/fpi/fast/l2/des-dist/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms2_fpi_fast_des-moms',
#    'loc': 's3://helio-public/MMS/mms2/fpi/fast/l2/des-moms/',
#    'title': 'mms2/fpi/fast/l2/des-moms/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms2_fpi_fast_dis-dist',
#    'loc': 's3://helio-public/MMS/mms2/fpi/fast/l2/dis-dist/',
#    'title': 'mms2/fpi/fast/l2/dis-dist/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms2_fpi_fast_dis-moms',
#    'loc': 's3://helio-public/MMS/mms2/fpi/fast/l2/dis-moms/',
#    'title': 'mms2/fpi/fast/l2/dis-moms/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms2_mec_brst_epht89d',
#    'loc': 's3://helio-public/MMS/mms2/mec/brst/l2/epht89d/',
#    'title': 'mms2/mec/brst/l2/epht89d/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms2_mec_srvy_epht89d',
#    'loc': 's3://helio-public/MMS/mms2/mec/srvy/l2/epht89d/',
#    'title': 'mms2/mec/srvy/l2/epht89d/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms3_feeps_brst_electron',
#    'loc': 's3://helio-public/MMS/mms3/feeps/brst/l2/electron/',
#    'title': 'mms3/feeps/brst/l2/electron/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms3_feeps_brst_ion',
#    'loc': 's3://helio-public/MMS/mms3/feeps/brst/l2/ion/',
#    'title': 'mms3/feeps/brst/l2/ion/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms3_feeps_srvy_electron',
#    'loc': 's3://helio-public/MMS/mms3/feeps/srvy/l2/electron/',
#    'title': 'mms3/feeps/srvy/l2/electron/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms3_feeps_srvy_ion',
#    'loc': 's3://helio-public/MMS/mms3/feeps/srvy/l2/ion/',
#    'title': 'mms3/feeps/srvy/l2/ion/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms3_fgm_brst',
#    'loc': 's3://helio-public/MMS/mms3/fgm/brst/l2/',
#    'title': 'mms3/fgm/brst/l2/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms3_fgm_srvy',
#    'loc': 's3://helio-public/MMS/mms3/fgm/srvy/l2/',
#    'title': 'mms3/fgm/srvy/l2/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms3_fpi_brst_des-dist',
#    'loc': 's3://helio-public/MMS/mms3/fpi/brst/l2/des-dist/',
#    'title': 'mms3/fpi/brst/l2/des-dist/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms3_fpi_brst_des-moms',
#    'loc': 's3://helio-public/MMS/mms3/fpi/brst/l2/des-moms/',
#    'title': 'mms3/fpi/brst/l2/des-moms/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms3_fpi_brst_dis-dist',
#    'loc': 's3://helio-public/MMS/mms3/fpi/brst/l2/dis-dist/',
#    'title': 'mms3/fpi/brst/l2/dis-dist/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms3_fpi_brst_dis-moms',
#    'loc': 's3://helio-public/MMS/mms3/fpi/brst/l2/dis-moms/',
#    'title': 'mms3/fpi/brst/l2/dis-moms/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms3_fpi_fast_des-dist',
#    'loc': 's3://helio-public/MMS/mms3/fpi/fast/l2/des-dist/',
#    'title': 'mms3/fpi/fast/l2/des-dist/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms3_fpi_fast_des-moms',
#    'loc': 's3://helio-public/MMS/mms3/fpi/fast/l2/des-moms/',
#    'title': 'mms3/fpi/fast/l2/des-moms/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms3_fpi_fast_dis-dist',
#    'loc': 's3://helio-public/MMS/mms3/fpi/fast/l2/dis-dist/',
#    'title': 'mms3/fpi/fast/l2/dis-dist/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms3_fpi_fast_dis-moms',
#    'loc': 's3://helio-public/MMS/mms3/fpi/fast/l2/dis-moms/',
#    'title': 'mms3/fpi/fast/l2/dis-moms/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms3_mec_brst_epht89d',
#    'loc': 's3://helio-public/MMS/mms3/mec/brst/l2/epht89d/',
#    'title': 'mms3/mec/brst/l2/epht89d/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms3_mec_srvy_epht89d',
#    'loc': 's3://helio-public/MMS/mms3/mec/srvy/l2/epht89d/',
#    'title': 'mms3/mec/srvy/l2/epht89d/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms4_feeps_brst_electron',
#    'loc': 's3://helio-public/MMS/mms4/feeps/brst/l2/electron/',
#    'title': 'mms4/feeps/brst/l2/electron/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms4_feeps_brst_ion',
#    'loc': 's3://helio-public/MMS/mms4/feeps/brst/l2/ion/',
#    'title': 'mms4/feeps/brst/l2/ion/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms4_feeps_srvy_electron',
#    'loc': 's3://helio-public/MMS/mms4/feeps/srvy/l2/electron/',
#    'title': 'mms4/feeps/srvy/l2/electron/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms4_feeps_srvy_ion',
#    'loc': 's3://helio-public/MMS/mms4/feeps/srvy/l2/ion/',
#    'title': 'mms4/feeps/srvy/l2/ion/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms4_fgm_brst',
#    'loc': 's3://helio-public/MMS/mms4/fgm/brst/l2/',
#    'title': 'mms4/fgm/brst/l2/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms4_fgm_srvy',
#    'loc': 's3://helio-public/MMS/mms4/fgm/srvy/l2/',
#    'title': 'mms4/fgm/srvy/l2/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms4_fpi_brst_des-dist',
#    'loc': 's3://helio-public/MMS/mms4/fpi/brst/l2/des-dist/',
#    'title': 'mms4/fpi/brst/l2/des-dist/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms4_fpi_brst_des-moms',
#    'loc': 's3://helio-public/MMS/mms4/fpi/brst/l2/des-moms/',
#    'title': 'mms4/fpi/brst/l2/des-moms/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms4_fpi_brst_dis-dist',
#    'loc': 's3://helio-public/MMS/mms4/fpi/brst/l2/dis-dist/',
#    'title': 'mms4/fpi/brst/l2/dis-dist/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms4_fpi_brst_dis-moms',
#    'loc': 's3://helio-public/MMS/mms4/fpi/brst/l2/dis-moms/',
#    'title': 'mms4/fpi/brst/l2/dis-moms/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms4_fpi_fast_des-dist',
#    'loc': 's3://helio-public/MMS/mms4/fpi/fast/l2/des-dist/',
#    'title': 'mms4/fpi/fast/l2/des-dist/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms4_fpi_fast_des-moms',
#    'loc': 's3://helio-public/MMS/mms4/fpi/fast/l2/des-moms/',
#    'title': 'mms4/fpi/fast/l2/des-moms/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms4_fpi_fast_dis-dist',
#    'loc': 's3://helio-public/MMS/mms4/fpi/fast/l2/dis-dist/',
#    'title': 'mms4/fpi/fast/l2/dis-dist/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms4_fpi_fast_dis-moms',
#    'loc': 's3://helio-public/MMS/mms4/fpi/fast/l2/dis-moms/',
#    'title': 'mms4/fpi/fast/l2/dis-moms/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms4_mec_brst_epht89d',
#    'loc': 's3://helio-public/MMS/mms4/mec/brst/l2/epht89d/',
#    'title': 'mms4/mec/brst/l2/epht89d/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'},
#   {'id': 'mms4_mec_srvy_epht89d',
#    'loc': 's3://helio-public/MMS/mms4/mec/srvy/l2/epht89d/',
#    'title': 'mms4/mec/srvy/l2/epht89d/',
#    'startDate': '2015-06-01T00:00:00Z',
#    'stopDate': '2021-12-31T23:59:00Z',
#    'modificationDate': '2023-03-08T00:00:00Z',
#    'indexformat': 'csv',
#    'fileformat': 'cdf'}],
#  'status': {'code': 1200, 'message': 'OK request successful'}}

# %%
pprint(fr.get_entries())
# Out:
# [('mms1_feeps_brst_electron', 'mms1/feeps/brst/l2/electron/'),
#  ('mms1_feeps_brst_ion', 'mms1/feeps/brst/l2/ion/'),
#  ('mms1_feeps_srvy_electron', 'mms1/feeps/srvy/l2/electron/'),
#  ('mms1_feeps_srvy_ion', 'mms1/feeps/srvy/l2/ion/'),
#  ('mms1_fgm_brst', 'mms1/fgm/brst/l2/'),
#  ('mms1_fgm_srvy', 'mms1/fgm/srvy/l2/'),
#  ('mms1_fpi_brst_des-dist', 'mms1/fpi/brst/l2/des-dist/'),
#  ('mms1_fpi_brst_des-moms', 'mms1/fpi/brst/l2/des-moms/'),
#  ('mms1_fpi_brst_dis-dist', 'mms1/fpi/brst/l2/dis-dist/'),
#  ('mms1_fpi_brst_dis-moms', 'mms1/fpi/brst/l2/dis-moms/'),
#  ('mms1_fpi_fast_des-dist', 'mms1/fpi/fast/l2/des-dist/'),
#  ('mms1_fpi_fast_des-moms', 'mms1/fpi/fast/l2/des-moms/'),
#  ('mms1_fpi_fast_dis-dist', 'mms1/fpi/fast/l2/dis-dist/'),
#  ('mms1_fpi_fast_dis-moms', 'mms1/fpi/fast/l2/dis-moms/'),
#  ('mms1_mec_brst_epht89d', 'mms1/mec/brst/l2/epht89d/'),
#  ('mms1_mec_srvy_epht89d', 'mms1/mec/srvy/l2/epht89d/'),
#  ('mms2_feeps_brst_electron', 'mms2/feeps/brst/l2/electron/'),
#  ('mms2_feeps_brst_ion', 'mms2/feeps/brst/l2/ion/'),
#  ('mms2_feeps_srvy_electron', 'mms2/feeps/srvy/l2/electron/'),
#  ('mms2_feeps_srvy_ion', 'mms2/feeps/srvy/l2/ion/'),
#  ('mms2_fgm_brst', 'mms2/fgm/brst/l2/'),
#  ('mms2_fgm_srvy', 'mms2/fgm/srvy/l2/'),
#  ('mms2_fpi_brst_des-dist', 'mms2/fpi/brst/l2/des-dist/'),
#  ('mms2_fpi_brst_des-moms', 'mms2/fpi/brst/l2/des-moms/'),
#  ('mms2_fpi_brst_dis-dist', 'mms2/fpi/brst/l2/dis-dist/'),
#  ('mms2_fpi_brst_dis-moms', 'mms2/fpi/brst/l2/dis-moms/'),
#  ('mms2_fpi_fast_des-dist', 'mms2/fpi/fast/l2/des-dist/'),
#  ('mms2_fpi_fast_des-moms', 'mms2/fpi/fast/l2/des-moms/'),
#  ('mms2_fpi_fast_dis-dist', 'mms2/fpi/fast/l2/dis-dist/'),
#  ('mms2_fpi_fast_dis-moms', 'mms2/fpi/fast/l2/dis-moms/'),
#  ('mms2_mec_brst_epht89d', 'mms2/mec/brst/l2/epht89d/'),
#  ('mms2_mec_srvy_epht89d', 'mms2/mec/srvy/l2/epht89d/'),
#  ('mms3_feeps_brst_electron', 'mms3/feeps/brst/l2/electron/'),
#  ('mms3_feeps_brst_ion', 'mms3/feeps/brst/l2/ion/'),
#  ('mms3_feeps_srvy_electron', 'mms3/feeps/srvy/l2/electron/'),
#  ('mms3_feeps_srvy_ion', 'mms3/feeps/srvy/l2/ion/'),
#  ('mms3_fgm_brst', 'mms3/fgm/brst/l2/'),
#  ('mms3_fgm_srvy', 'mms3/fgm/srvy/l2/'),
#  ('mms3_fpi_brst_des-dist', 'mms3/fpi/brst/l2/des-dist/'),
#  ('mms3_fpi_brst_des-moms', 'mms3/fpi/brst/l2/des-moms/'),
#  ('mms3_fpi_brst_dis-dist', 'mms3/fpi/brst/l2/dis-dist/'),
#  ('mms3_fpi_brst_dis-moms', 'mms3/fpi/brst/l2/dis-moms/'),
#  ('mms3_fpi_fast_des-dist', 'mms3/fpi/fast/l2/des-dist/'),
#  ('mms3_fpi_fast_des-moms', 'mms3/fpi/fast/l2/des-moms/'),
#  ('mms3_fpi_fast_dis-dist', 'mms3/fpi/fast/l2/dis-dist/'),
#  ('mms3_fpi_fast_dis-moms', 'mms3/fpi/fast/l2/dis-moms/'),
#  ('mms3_mec_brst_epht89d', 'mms3/mec/brst/l2/epht89d/'),
#  ('mms3_mec_srvy_epht89d', 'mms3/mec/srvy/l2/epht89d/'),
#  ('mms4_feeps_brst_electron', 'mms4/feeps/brst/l2/electron/'),
#  ('mms4_feeps_brst_ion', 'mms4/feeps/brst/l2/ion/'),
#  ('mms4_feeps_srvy_electron', 'mms4/feeps/srvy/l2/electron/'),
#  ('mms4_feeps_srvy_ion', 'mms4/feeps/srvy/l2/ion/'),
#  ('mms4_fgm_brst', 'mms4/fgm/brst/l2/'),
#  ('mms4_fgm_srvy', 'mms4/fgm/srvy/l2/'),
#  ('mms4_fpi_brst_des-dist', 'mms4/fpi/brst/l2/des-dist/'),
#  ('mms4_fpi_brst_des-moms', 'mms4/fpi/brst/l2/des-moms/'),
#  ('mms4_fpi_brst_dis-dist', 'mms4/fpi/brst/l2/dis-dist/'),
#  ('mms4_fpi_brst_dis-moms', 'mms4/fpi/brst/l2/dis-moms/'),
#  ('mms4_fpi_fast_des-dist', 'mms4/fpi/fast/l2/des-dist/'),
#  ('mms4_fpi_fast_des-moms', 'mms4/fpi/fast/l2/des-moms/'),
#  ('mms4_fpi_fast_dis-dist', 'mms4/fpi/fast/l2/dis-dist/'),
#  ('mms4_fpi_fast_dis-moms', 'mms4/fpi/fast/l2/dis-moms/'),
#  ('mms4_mec_brst_epht89d', 'mms4/mec/brst/l2/epht89d/'),
#  ('mms4_mec_srvy_epht89d', 'mms4/mec/srvy/l2/epht89d/')]

# %%
fr_id1 = 'mms1_feeps_brst_electron'
fr_id2 = 'mmm2_feeps_brst_electron'
start_date = '2020-02-01T00:00:00Z'
stop_date =   '2020-02-02T00:00:00Z'

# %%
#pprint(fr.get_catalog()['catalog'])
pprint(fr.get_entry(fr_id1))
# Out:
# {'aboutURL': 'optional website URL for info, team, etc',
#  'citation': 'optional how to cite this dataset, DOI or similar',
#  'contact': 'optional contact info, SPASE ID, email, or ORCID',
#  'creationDate': '2023-04-05T00:00:00Z',
#  'description': 'Optional description for dataset',
#  'fileformat': 'cdf',
#  'id': 'mms1_feeps_brst_electron',
#  'indexformat': 'csv',
#  'loc': 's3://helio-public/MMS/mms1/feeps/brst/l2/electron/',
#  'modificationDate': '2023-03-08T00:00:00Z',
#  'resourceURL': 'optional identifier e.g. SPASE ID',
#  'startDate': '2015-06-01T00:00:00Z',
#  'stopDate': '2021-12-31T23:59:00Z',
#  'title': 'mms1/feeps/brst/l2/electron/'}

# %%
file_registry1 = fr.request_file_registry(fr_id1, start_date=start_date, stop_date=stop_date, overwrite=False)

# %%
file_registry1
# Out:
#               startDate                                                key  \
# 590 2020-02-01 07:55:23  s3://helio-public/MMS/mms1/feeps/brst/l2/elect...
# 591 2020-02-01 08:17:13  s3://helio-public/MMS/mms1/feeps/brst/l2/elect...
# 592 2020-02-01 08:19:23  s3://helio-public/MMS/mms1/feeps/brst/l2/elect...
# 593 2020-02-01 08:21:33  s3://helio-public/MMS/mms1/feeps/brst/l2/elect...
# 594 2020-02-01 08:23:43  s3://helio-public/MMS/mms1/feeps/brst/l2/elect...
# 595 2020-02-01 08:26:03  s3://helio-public/MMS/mms1/feeps/brst/l2/elect...
# 596 2020-02-01 08:28:13  s3://helio-public/MMS/mms1/feeps/brst/l2/elect...
# 597 2020-02-01 08:30:23  s3://helio-public/MMS/mms1/feeps/brst/l2/elect...
# 598 2020-02-01 08:37:13  s3://helio-public/MMS/mms1/feeps/brst/l2/elect...
# 599 2020-02-01 08:39:33  s3://helio-public/MMS/mms1/feeps/brst/l2/elect...
# 600 2020-02-01 08:41:53  s3://helio-public/MMS/mms1/feeps/brst/l2/elect...
# 601 2020-02-01 08:44:13  s3://helio-public/MMS/mms1/feeps/brst/l2/elect...
# 602 2020-02-01 08:46:33  s3://helio-public/MMS/mms1/feeps/brst/l2/elect...
# 603 2020-02-01 08:48:53  s3://helio-public/MMS/mms1/feeps/brst/l2/elect...
#
#      filesize
# 590   1521034
# 591   3166628
# 592   3166628
# 593   3166628
# 594   3396580
# 595   3166628
# 596   3159442
# 597   3152256
# 598   3396580
# 599   3396580
# 600   3403766
# 601   3396580
# 602   3396580
# 603   3389394

# %%
print('Python Hash of File | Start Date | File Size')
fr.stream(file_registry1, lambda bo, d, f: print(hash(bo.read()), d.replace(' ', 'T')+'Z', f))
# Out:
# Python Hash of File | Start Date | File Size
# 4378224926715883144 2020-02-01T07:55:23Z 1521034
# 2044434010877765843 2020-02-01T08:17:13Z 3166628
# 3139975076887218535 2020-02-01T08:19:23Z 3166628
# -6895490577946462752 2020-02-01T08:21:33Z 3166628
# -6178651076052319741 2020-02-01T08:23:43Z 3396580
# 5869130449305920995 2020-02-01T08:26:03Z 3166628
# 5403265598136592399 2020-02-01T08:28:13Z 3159442
# 8713372122426702853 2020-02-01T08:30:23Z 3152256
# 2049431613195395467 2020-02-01T08:37:13Z 3396580
# -6188029821026086922 2020-02-01T08:39:33Z 3396580
# 6463331033822005653 2020-02-01T08:41:53Z 3403766
# -8303172767393965708 2020-02-01T08:44:13Z 3396580
# 1016551622362861071 2020-02-01T08:46:33Z 3396580
# 8688708534051050857 2020-02-01T08:48:53Z 3389394

# %%
def plot_cdf(s3_uri, d, f):
    print(len(cdflib.CDF(s3_uri).cdf_info()["zVariables"]), d.replace(' ', 'T')+'Z', f)
    
    cdf = cdflib.CDF(s3_uri)

    # Get the variable name and its data
    var_name = cdf.cdf_info()["zVariables"][2]
    var_data = cdf.varget(var_name)

    # Plot the variable
    plt.figure()
    plt.plot(var_data)
    plt.xlabel("Index")
    plt.ylabel(var_name)
    plt.title(f"Plot of {var_name}")
    plt.show()

print('# of zVariables | Start Date | File Size')
fr.stream_uri(file_registry1[:2], lambda s3_uri, d, f: plot_cdf(s3_uri, d, f))
# Out:
# # of zVariables | Start Date | File Size
# 77 2020-02-01T07:55:23Z 1521034
# 77 2020-02-01T08:17:13Z 3166628

# %%
# Fail on purpose - invalid catalog entry
file_registry2 = fr.request_file_registry(fr_id2, start_date=start_date, stop_date=stop_date, overwrite=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [25], line 2
#       1 # Fail on purpose - invalid catalog entry
# ----> 2 file_registry2 = fr.request_file_registry(fr_id2, start_date=start_date, stop_date=stop_date, overwrite=False)
#
# File ~/work/file registry/registry.py:266, in FileRegistry.request_file_registry(self, catalog_id, start_date, stop_date, overwrite)
#     264 # Raises error if no matching entry is found
#     265 if len(entry) == 0:
# --> 266     raise KeyError(f'No catalog entry found with id: {catalog_id}')
#     267 elif len(entry) > 1:
#     268     raise ValueError(f'No unique catalog entry found with id: {catalog_id}')
#
# KeyError: 'No catalog entry found with id: mmm2_feeps_brst_electron'
